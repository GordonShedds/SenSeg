# %%
from utils.featurizer import SentinelFeaturizer
import numpy as np

# %% [markdown]
# ## Now, lets read image with corresponding mask (in vector format)
#
# Mask will be rasterized accordingly

# %%
featurizer = SentinelFeaturizer(image='sentinel_data_4_bands.tif',
                                mask='mask.geojson')
featurizer.normalize()
featurizer.plot(tile_size=64, mask_alpha=0.3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## We can extract both image windowed features and labels from mask
#
# Using the same interface as in previous tutorial

# %%
X, y = featurizer.get_features(window_size=3)

print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (31824, 36)
# y shape: (31824,)

# %% [markdown]
# ## Those data arrays can be directly used for supervised learning!
